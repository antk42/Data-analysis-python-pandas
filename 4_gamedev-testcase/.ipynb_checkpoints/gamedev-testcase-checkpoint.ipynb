# %% [markdown]
# # Introducing:

# %% [markdown]
# ## Content:
# Входные данные — файл plr_smpl_attempts.csv.gz, содержащий лог событий за
# определенный промежуток времени по первым 500 уровням в игре.
# Файл содержит четыре колонки:
# - uid — уникальный id игрока;
# - action — ‘completed’ для успешной попытки прохождения уровня, ‘failed’ для неуспешной;
# - level — уровень, на котором произошло событие;
# - event_time — event_time/1000 является unix timestamp времени получения события.

# %% [markdown]
# ## Task:
#
# *Задание 1:*
# - Предложить метрику, описывающую сложность уровней, и рассчитать ее.
#
# *Задание 2:*
# - По результатам предыдущего задания разделить уровни на группы по сложности и сделать вывод о плотности расположения сложных уровней в игре.
#
# *Задание 3:*
# - Рассчитать "воронку" прохождения уровней новым пользователем после установки игры.

# %% [markdown]
# ## Used libraries:
# - pandas
# - numpy
# - matplotlib
# - phik

# %%
import pandas as pd
import numpy as np
import phik

import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv('/home/antonius/Projects/DS_Projects/Data-analysis-python-pandas/4_gamedev-testcase/data/plr_smpl_attempts.csv.gz',
                sep=';')
df.head(5)
# Out:
#                               uid  action  level     event_time
# 0  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 1  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 2  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 3  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 4  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640

# %% [markdown]
# ## Format data

# %%
len(df)
# Out:
# 22231214

# %%
df.value_counts('action')
# Out:
# action
# failed       18744535
# completed     3486679
# dtype: int64

# %%
df['action'] = df['action'].replace('failed',1).replace('completed',0)

# %% [markdown]
# ### Skips, Nans

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# uid           0.0
# action        0.0
# level         0.0
# event_time    0.0
# dtype: float64

# %% [markdown]
# # Phik

# %%
phik_overview = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['action', 'level', 'event_time']
# /home/antonius/.local/lib/python3.10/site-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable uid is large: 196088. Are you sure this is not an interval variable? Analysis for pairs of variables including uid can be slow.
#   warnings.warn(

# %%
(phik_overview['level'].sort_values(ascending=False).reset_index()
.style
.highlight_between(left=.3, right=1, subset='level', color='red' )
.highlight_between(left=.1, right=.3, subset='level', color='orange' )
.highlight_between(left=0, right=.1, subset='level', color='green' )

.format({
    'default': '{:,.2%}'.format,
})
)
# Out:
# <style type="text/css">
# #T_a1b5b_row0_col1, #T_a1b5b_row1_col1 {
#   background-color: red;
# }
# #T_a1b5b_row2_col1, #T_a1b5b_row3_col1 {
#   background-color: orange;
# }
# </style>
# <table id="T_a1b5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1b5b_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a1b5b_level0_col1" class="col_heading level0 col1" >level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1b5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1b5b_row0_col0" class="data row0 col0" >level</td>
#       <td id="T_a1b5b_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1b5b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1b5b_row1_col0" class="data row1 col0" >uid</td>
#       <td id="T_a1b5b_row1_col1" class="data row1 col1" >0.947529</td>
#     </tr>
#     <tr>
#       <th id="T_a1b5b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1b5b_row2_col0" class="data row2 col0" >event_time</td>
#       <td id="T_a1b5b_row2_col1" class="data row2 col1" >0.195596</td>
#     </tr>
#     <tr>
#       <th id="T_a1b5b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1b5b_row3_col0" class="data row3 col0" >action</td>
#       <td id="T_a1b5b_row3_col1" class="data row3 col1" >0.190753</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Analysis:

# %% [markdown]
# # Доля неудачных попыток на каждом уровне

# %%
df.groupby('level')['action'].agg(['count','mean'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:192, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
# --> 192     raise NotImplementedError(
#     193         f"function is not implemented for this dtype: "
#     194         f"[how->{how},dtype->{dtype_str}]"
#     195     )
#     196 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df.groupby('level')['action'].agg(['count','mean'])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/generic.py:281, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     277 elif isinstance(func, abc.Iterable):
#     278     # Catch instances of lists / tuples
#     279     # but not the class list / tuple itself.
#     280     func = maybe_mangle_lambdas(func)
# --> 281     ret = self._aggregate_multiple_funcs(func)
#     282     if relabeling:
#     283         # columns is not narrowed by mypy from relabeling flag
#     284         assert columns is not None  # for mypy
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/generic.py:336, in SeriesGroupBy._aggregate_multiple_funcs(self, arg)
#     333 for idx, (name, func) in enumerate(arg):
#     335     key = base.OutputKey(label=name, position=idx)
# --> 336     results[key] = self.aggregate(func)
#     338 if any(isinstance(x, DataFrame) for x in results.values()):
#     339     from pandas import concat
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/generic.py:275, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     272     kwargs = {}
#     274 if isinstance(func, str):
# --> 275     return getattr(self, func)(*args, **kwargs)
#     277 elif isinstance(func, abc.Iterable):
#     278     # Catch instances of lists / tuples
#     279     # but not the class list / tuple itself.
#     280     func = maybe_mangle_lambdas(func)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2183, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
# -> 2183     result = self._cython_agg_general(
#    2184         "mean",
#    2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1810, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1806     return result
#    1808 # TypeError -> we may have an exception in trying to aggregate
#    1809 #  continue and exclude the block
# -> 1810 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1812 if not is_ser and len(new_mgr) < orig_len:
#    1813     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1804, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    (...)
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
# -> 1804     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1806 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1745, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1740     ser = df.iloc[:, 0]
#    1742 # We do not get here with UDFs, so we know that our dtype
#    1743 #  should always be preserved by the implemented aggregations
#    1744 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1745 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1747 if isinstance(values, Categorical):
#    1748     # Because we only get here with known dtype-preserving
#    1749     #  reductions, we cast back to Categorical.
#    1750     # TODO: if we ever get "rank" working, exclude it here.
#    1751     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2185, in GroupBy.mean.<locals>.<lambda>(x)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
#    2183     result = self._cython_agg_general(
#    2184         "mean",
# -> 2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert ... to numeric

# %%
df.groupby('level')['action'].mean().plot()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:192, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
# --> 192     raise NotImplementedError(
#     193         f"function is not implemented for this dtype: "
#     194         f"[how->{how},dtype->{dtype_str}]"
#     195     )
#     196 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df.groupby('level')['action'].mean().plot()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2183, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
# -> 2183     result = self._cython_agg_general(
#    2184         "mean",
#    2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1810, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1806     return result
#    1808 # TypeError -> we may have an exception in trying to aggregate
#    1809 #  continue and exclude the block
# -> 1810 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1812 if not is_ser and len(new_mgr) < orig_len:
#    1813     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1804, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    (...)
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
# -> 1804     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1806 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1745, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1740     ser = df.iloc[:, 0]
#    1742 # We do not get here with UDFs, so we know that our dtype
#    1743 #  should always be preserved by the implemented aggregations
#    1744 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1745 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1747 if isinstance(values, Categorical):
#    1748     # Because we only get here with known dtype-preserving
#    1749     #  reductions, we cast back to Categorical.
#    1750     # TODO: if we ever get "rank" working, exclude it here.
#    1751     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2185, in GroupBy.mean.<locals>.<lambda>(x)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
#    2183     result = self._cython_agg_general(
#    2184         "mean",
# -> 2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert ... to numeric

# %% [markdown]
# # Доля игроков которые не прошли уровень с первого раза

# %%
df.head(3)
# Out:
#                               uid  action  level     event_time
# 0  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640
# 1  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640
# 2  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640

# %%
t = df[df['level'] == 113].copy()

# %%
t['rnk'] = t.sort_values('event_time').groupby(['level','uid'])['event_time'].rank(method='first')

# %%
t[t['rnk'] == 1]
# Out:
#                                      uid  action  level     event_time  rnk
# 0         elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640  1.0
# 426       RE9iT0VkMmkwMjUwMTI3MTAyMDE4MA       1    113  1512146434418  1.0
# 1354      cDBlZlZuRjAwMzU1NDE3MTAyMTE4Mg       1    113  1512096831695  1.0
# 1612      a2FqVG5mcTQyMjcwODA3MTAyOTA4Mg       0    113  1512097744297  1.0
# 3271      WHNRT1ZPTzQ2MzIzOTA3MTAyMDE0MQ       0    113  1512136177025  1.0
# ...                                  ...     ...    ...            ...  ...
# 22226613  Z0pxTkk3T2w4MTUxNjE3MTAyMTEyMg       1    113  1514188686859  1.0
# 22227559  THZIYXZVaU01MjgyMTE3MTAyMTEzMA       1    113  1514204444724  1.0
# 22227810  SzJvRXcxOEIwMzk0MjE3MTAyOTA4Mg       1    113  1514230050322  1.0
# 22228410  NGtWM2pCaG43MTI1NDE3MTAyOTAwMw       1    113  1514203803703  1.0
# 22229183  aVhaY3RjZEY1MDQzMDI3MTAyMTE0MQ       1    113  1514207760591  1.0
#
# [17278 rows x 5 columns]

# %%
tt = t.sort_values('event_time').groupby(['level','uid'])[['event_time','action']].first().reset_index()

# %%
tt[tt['uid'] == 'M000Y3dYeUUyMjIxODE3MTAyOTAwMQ']
# Out:
#    level                             uid     event_time  action
# 0    113  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ  1513482740555       1

# %%
t[(t['rnk'] == 1)&(t['uid']=='M000Y3dYeUUyMjIxODE3MTAyOTAwMQ')]
# Out:
#                                      uid  action  level     event_time  rnk
# 10987832  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555  1.0

# %%
t[t['uid']=='M000Y3dYeUUyMjIxODE3MTAyOTAwMQ'].sort_values('event_time')
# Out:
#                                      uid  action  level     event_time   rnk
# 10987828  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555   5.0
# 10987829  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555   4.0
# 10987830  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555   3.0
# 10987831  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555   2.0
# 10987832  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555   1.0
# 10987836  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513540538178   7.0
# 10987837  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513540538178   6.0
# 10987838  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513542854279   8.0
# 10987839  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513542854279  10.0
# 10987840  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513542854279   9.0
# 10987841  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513547997358  11.0
# 10987842  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513547997358  12.0
# 10987843  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513547997358  13.0
# 10987833  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513553908542  14.0
# 10987834  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513553908542  16.0
# 10987835  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513553908542  15.0

# %%
len(df)
# Out:
# 22231214

# %%
len(df.drop_duplicates())
# Out:
# 10387712

# %%
df.head()
# Out:
#                               uid  action  level     event_time
# 0  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640
# 1  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640
# 2  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640
# 3  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640
# 4  elljQ2EySG03MDU0MTE3MTAyMTE3MA       1    113  1512086924640

# %%
df.columns
# Out:
# Index(['uid', 'action', 'level', 'event_time'], dtype='object')

# %%
df = df.groupby(['uid', 'action', 'level', 'event_time'])['uid'].count()

# %%
df.name = 'count'

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#                               uid  action  level     event_time  count
# 0  M000MjVPdEM0MzMzNzA3MTAyMDE5MQ       1     95  1513224808476      5
# 1  M000MjVPdEM0MzMzNzA3MTAyMDE5MQ       1     95  1513253353017      1
# 2  M000MjVPdEM0MzMzNzA3MTAyMDE5MQ       1     95  1513253543747      2
# 3  M000MjVPdEM0MzMzNzA3MTAyMDE5MQ       1     95  1513261453988      6
# 4  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       0     90  1512249715495      1

# %%
df[(df['uid']=='M000Y3dYeUUyMjIxODE3MTAyOTAwMQ')&(df['level']==113)].sort_values('event_time')
# Out:
#                                uid  action  level     event_time  count
# 76  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513482740555      5
# 77  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513540538178      2
# 78  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513542854279      3
# 79  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513547997358      3
# 80  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1    113  1513553908542      3

# %%
t = df.sort_values(['level','uid','event_time']).groupby(['level','uid']).first().reset_index()

# %%
t[(t['uid']=='M000Y3dYeUUyMjIxODE3MTAyOTAwMQ')&(t['level']==113)].sort_values('event_time')
# Out:
#          level                             uid  action     event_time  count
# 1838469    113  M000Y3dYeUUyMjIxODE3MTAyOTAwMQ       1  1513482740555      5

# %%
t.sample(5)
# Out:
#          level                             uid  action     event_time  count
# 771638      47  V0tmdFlDbEMwMTc0NTE3MTAyMTE4Mg       1  1512305760809      2
# 2733724    172  NVpJT2tIdEgwNTU1OTE3MTAyMjE2MQ       0  1514076561187      1
# 3361880    249  ZFZTd21kV0E4Mjk1MTE3MTAyMDE5MA       1  1513514586926      4
# 887884      55  VTI1QlpDSks0MTAzMjI3MTAyMTE4MA       1  1512707267276      3
# 425722      24  WFlLb1FRZ2o5MzI0NzA3MTAyMjEyMA       0  1512267234107      1

# %%
df[(df['uid']=='cGlrbVhNNTAyNTE1NzE3MTAyMjE4MA')&(df['level']==91)].sort_values('event_time')
# Out:
#                                     uid  action  level     event_time  count
# 8814631  cGlrbVhNNTAyNTE1NzE3MTAyMjE4MA       0     91  1514679041474      1
# 8814690  cGlrbVhNNTAyNTE1NzE3MTAyMjE4MA       1     91  1514679041474      2

# %%
t[(t['uid']=='cGlrbVhNNTAyNTE1NzE3MTAyMjE4MA')&(t['level']==91)].sort_values('event_time')
# Out:
#          level                             uid  action     event_time  count
# 1470944     91  cGlrbVhNNTAyNTE1NzE3MTAyMjE4MA       0  1514679041474      1

# %%
t.columns = ['level', 'uid', 'failed', 'event_time', 'count']

# %%
t.head()
# Out:
#    level                             uid  failed     event_time  count
# 0      1  M001TWRFNWc5MjQ1MDI3MTAyMjE5MA       0  1512855813696      1
# 1      1  M001VTlGalU5MzcwMTI3MTAyMjE5Mg       0  1514578577760      1
# 2      1  M010Z2VmOFgzMzgwMTI3MTAyMjE4Mg       0  1514489117415      1
# 3      1  M01QQlBMVmo1NTcyODA3MTAyMjE4MQ       0  1513557080655      1
# 4      1  M01TMDNDdzA0MDkwNzE3MTAyMjE2MA       0  1512535403271      1

# %%
t['comleted'] = t['failed'].apply(lambda x: 1 if 0 else 0)

# %%
t['failed'].replace(0,1).replace(1,0).reset_index()
# Out:
#            index  failed
# 0              0       0
# 1              1       0
# 2              2       0
# 3              3       0
# 4              4       0
# ...          ...     ...
# 3803853  3803853       0
# 3803854  3803854       0
# 3803855  3803855       0
# 3803856  3803856       0
# 3803857  3803857       0
#
# [3803858 rows x 2 columns]

# %%
t.groupby('level')['failed'].mean().plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
df = pd.read_csv('/home/antonius/Projects/DS_Projects/Data-analysis-python-pandas/4_gamedev-testcase/data/plr_smpl_attempts.csv.gz',
                sep=';')
df.head(5)
# Out:
#                               uid  action  level     event_time
# 0  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 1  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 2  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 3  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640
# 4  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640

# %%
t = df.groupby(['uid','event_time'])['uid'].count()

# %%
t.sort_values()
# Out:
# uid                             event_time
# enpzeGNhWUk4MjE0MzE3MTAyMDE5MA  1514674966884       1
# YzNLQ25tWTU4NTgzMjI3MTAyMDEyMA  1513914594387       1
# RUxHSnZTV3o5MTQyMTI3MTAyOTAyMg  1513744264460       1
# YzNMczF1RVUyMjMyMzI3MTAyMDE1MQ  1513675368301       1
#                                 1513705431024       1
#                                                  ...
# dlE1TGo1ZjU1NDExOTA3MTAyMDE5MA  1514078786418    1182
# SHIwdkltZlk0NTUxNjE3MTAyOTA5Mg  1514006798622    1233
# Z3o0TmFoeTQ1MjMyOTE3MTAyOTAxMg  1513449317511    1408
# U0NVNk4xSlAxMjc0MzE3MTAyMDE1MA  1514463213261    1561
# NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg  1514370274359    1688
# Name: uid, Length: 5486162, dtype: int64

# %%
df[(df['uid']=='NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg')&(df['event_time']==1514370274359)]
# Out:
#                                     uid     action  level     event_time
# 9641711  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg  completed    263  1514370274359
# 9641712  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    263  1514370274359
# 9641713  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg  completed    262  1514370274359
# 9641714  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    262  1514370274359
# 9641715  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    262  1514370274359
# ...                                 ...        ...    ...            ...
# 9643394  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    143  1514370274359
# 9643395  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    143  1514370274359
# 9643396  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    143  1514370274359
# 9643397  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    143  1514370274359
# 9643398  NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg     failed    143  1514370274359
#
# [1688 rows x 4 columns]

# %%
df[(df['uid']=='NWVTWWt4UzIxMDUxMTA3MTAyOTA5Mg')&(df['event_time']==1514370274359)]['level'].value_counts()
# Out:
# 154    344
# 144     77
# 197     54
# 214     53
# 167     50
#       ...
# 212      1
# 211      1
# 190      1
# 202      1
# 203      1
# Name: level, Length: 121, dtype: int64

# %% [markdown]
# # Доля тех кто отваливается поле уровня: либо на всегда, либо на время

# %% [markdown]
# # Количество уникальных пользаков играющих на уровне

# %% [markdown]
# Задание 1
# Предложить метрику, описывающую сложность уровней, и рассчитать ее.
#
# Задание 2
# По результатам предыдущего задания разделить уровни на группы по сложности и
# сделать вывод о плотности расположения сложных уровней в игре.
# Задание 3
# Рассчитать "воронку" прохождения уровней новым пользователем после установки
# игры.

# %%
df.groupby('level')['uid'].nunique().plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
df['failed'] = df['action'].replace('failed',1).replace('completed',0)

# %%
df.groupby('level')['failed'].mean().plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
df['uid'].nunique()
# Out:
# 196088

# %%
df
# Out:
#                                      uid     action  level     event_time  \
# 0         elljQ2EySG03MDU0MTE3MTAyMTE3MA     failed    113  1512086924640
# 1         elljQ2EySG03MDU0MTE3MTAyMTE3MA     failed    113  1512086924640
# 2         elljQ2EySG03MDU0MTE3MTAyMTE3MA     failed    113  1512086924640
# 3         elljQ2EySG03MDU0MTE3MTAyMTE3MA     failed    113  1512086924640
# 4         elljQ2EySG03MDU0MTE3MTAyMTE3MA     failed    113  1512086924640
# ...                                  ...        ...    ...            ...
# 22231209  R2l2aXM5bGM1MTExMzE3MTAyMDE4MQ     failed    214  1514189810163
# 22231210  R2l2aXM5bGM1MTExMzE3MTAyMDE4MQ     failed    214  1514189810163
# 22231211  R2l2aXM5bGM1MTExMzE3MTAyMDE4MQ  completed    213  1514189810163
# 22231212  R2l2aXM5bGM1MTExMzE3MTAyMDE4MQ     failed    213  1514189810163
# 22231213  R2l2aXM5bGM1MTExMzE3MTAyMDE4MQ     failed    214  1514192215548
#
#           failed
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 22231209       1
# 22231210       1
# 22231211       0
# 22231212       1
# 22231213       1
#
# [22231214 rows x 5 columns]

# %%
df['dt'] = pd.to_datetime(df['event_time']/1000,unit='s')

# %%
df.head()
# Out:
#                               uid  action  level     event_time  failed  \
# 0  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640       1
# 1  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640       1
# 2  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640       1
# 3  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640       1
# 4  elljQ2EySG03MDU0MTE3MTAyMTE3MA  failed    113  1512086924640       1
#
#                        dt
# 0 2017-12-01 00:08:44.640
# 1 2017-12-01 00:08:44.640
# 2 2017-12-01 00:08:44.640
# 3 2017-12-01 00:08:44.640
# 4 2017-12-01 00:08:44.640

# %%
df['dt'].agg(['min','max']).reset_index()
# Out:
#   index                            dt
# 0   min 2017-12-01 00:00:00.272000000
# 1   max 2017-12-31 23:59:59.867000064

# %%
df.groupby('level')['uid'].nunique().plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
df['uid'].nunique() * 31
# Out:
# 6078728

# %% [markdown]
# 1 1 89
# 1 2 -
# 1 3 -

# %% [markdown]
# Задание 1
# Предложить метрику, описывающую сложность уровней, и рассчитать ее.
#
# Задание 2
# По результатам предыдущего задания разделить уровни на группы по сложности и
# сделать вывод о плотности расположения сложных уровней в игре.
# Задание 3
# Рассчитать "воронку" прохождения уровней новым пользователем после установки
# игры.

# %%
df['day'] = df['dt'].dt.date

# %%
t = df.groupby('uid')['day'].min()

# %%
t = t.reset_index()

# %%
t.groupby('day')['uid'].count().plot(rot=45)
# Out:
# <AxesSubplot: xlabel='day'>

# %%
df['uid'].nunique()
# Out:
# 196088

# %%
df.groupby('day')['uid'].nunique().plot(rot=45,ylim=0)
# Out:
# <AxesSubplot: xlabel='day'>

# %%
df.groupby('level')['uid'].count().plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
t = df.groupby(['level','uid'])['uid'].count()

# %%
t.name = 'count'

# %%
t = t.reset_index()

# %%
t.head()
# Out:
#    level                             uid  count
# 0      1  M001TWRFNWc5MjQ1MDI3MTAyMjE5MA      1
# 1      1  M001VTlGalU5MzcwMTI3MTAyMjE5Mg      1
# 2      1  M010Z2VmOFgzMzgwMTI3MTAyMjE4Mg      1
# 3      1  M01QQlBMVmo1NTcyODA3MTAyMjE4MQ      1
# 4      1  M01TMDNDdzA0MDkwNzE3MTAyMjE2MA      1

# %%
tt = t.groupby('level')['count'].agg(['count','mean','median'])

# %%
tt.head()
# Out:
#        count      mean  median
# level
# 1      24162  1.041180     1.0
# 2      22177  1.051224     1.0
# 3      21415  1.103619     1.0
# 4      20916  1.034423     1.0
# 5      20625  1.318400     1.0

# %%
tt['count'].plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
tt['mean'].plot()
# Out:
# <AxesSubplot: xlabel='level'>

# %%
tt['median'].plot(figsize=(16,9))
# Out:
# <AxesSubplot: xlabel='level'>

# %%
tt = tt.reset_index('level')

# %%
tt.plot(x='level',y='count',kind='scatter')
# Out:
# <AxesSubplot: xlabel='level', ylabel='count'>

# %%
tt['median']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 495    3.0
# 496    2.0
# 497    4.0
# 498    3.0
# 499    5.0
# Name: median, Length: 500, dtype: float64

# %%
tt['median'].plot(kind='bar',figsize=(16,9))
# Out:
# <AxesSubplot: >

# %%
t = tt['median'].reset_index()

# %%
t['median'].value_counts().reset_index()
# Out:
#     index  median
# 0     3.0     124
# 1     4.0      94
# 2     2.0      88
# 3     5.0      70
# 4     6.0      50
# 5     7.0      39
# 6     1.0      19
# 7     8.0      12
# 8    10.0       2
# 9     9.0       1
# 10    8.5       1

# %% [markdown]
# Посмотреть только на тех пользователей, которые прошли с 1 до 200. с 1 по 400.
